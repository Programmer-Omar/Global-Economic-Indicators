# %% [markdown]
# * Important Libraries

# %%
import pandas as pd
import numpy as np
import kagglehub

# %% [markdown]
# ### Getting Kaggle API

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ace9cc71-5256-4d4b-9aad-dae71f0754c0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ace9cc71-5256-4d4b-9aad-dae71f0754c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d tanishksharma9905/global-economic-indicators-20102025
# Out:
# Dataset URL: https://www.kaggle.com/datasets/tanishksharma9905/global-economic-indicators-20102025
# License(s): CC0-1.0
# ...
#   0% 0.00/257k [00:00<?, ?B/s]
# 100% 257k/257k [00:00<00:00, 504MB/s]

# %% [markdown]
# * Unzip the Dataset

# %%
! unzip /content/global-economic-indicators-20102025.zip
# Out:
# Archive:  /content/global-economic-indicators-20102025.zip
#   inflating: world_bank_data_2025.csv

# %% [markdown]
# ### General Overview of the Dataset

# %%
ds = pd.read_csv("/content/world_bank_data_2025.csv")

# %% [markdown]
# * In this dataset, there are 3472 raw and 16 column

# %%
ds.shape
# Out:
# (3472, 16)

# %% [markdown]
# * From these samples, it's clear that there are some missing values

# %%
ds.sample(3)
# Out:
#           country_name country_id  year  Inflation (CPI %)  GDP (Current USD)  \
# 1545           Jamaica         jm  2019           3.905100       1.583077e+10
# 2028  Marshall Islands         mh  2022                NaN       2.534000e+08
# 2396              Oman         om  2022           2.506143       1.119438e+11
#
#       GDP per Capita (Current USD)  Unemployment Rate (%)  \
# 1545                   5607.243007                  4.987
# 2028                   6322.828555                    NaN
# 2396                  23665.639474                  3.300
#
#       Interest Rate (Real, %)  Inflation (GDP Deflator, %)  \
# 1545                 9.513194                     3.182503
# 2028                      NaN                    -1.017683
# 2396                      NaN                    16.989719
#
#       GDP Growth (% Annual)  Current Account Balance (% GDP)  \
# 1545               0.892292                        -1.911686
# ...

# %% [markdown]
# * There are 217 different country in this dataset

# %%
len(ds['country_name'].unique())
# Out:
# 217

# %% [markdown]
# * Here are the list of all the countries

# %%
ds['country_name'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada', 'Switzerland',
#        'Channel Islands', 'Chile', 'China', "Cote d'Ivoire", 'Cameroon',
#        'Congo, Dem. Rep.', 'Congo, Rep.', 'Colombia', 'Comoros',
#        'Cabo Verde', 'Costa Rica', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria', 'Ecuador', 'Egypt, Arab Rep.',
#        'Eritrea', 'Spain', 'Estonia', 'Ethiopia', 'Finland', 'Fiji',
# ...

# %% [markdown]
# * There are lots of information below, but the most important one is there are no issues in the Dtype

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3472 entries, 0 to 3471
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country_name                     3472 non-null   object
#  1   country_id                       3472 non-null   object
#  2   year                             3472 non-null   int64
#  3   Inflation (CPI %)                2694 non-null   float64
#  4   GDP (Current USD)                2933 non-null   float64
#  5   GDP per Capita (Current USD)     2938 non-null   float64
#  6   Unemployment Rate (%)            2795 non-null   float64
#  7   Interest Rate (Real, %)          1735 non-null   float64
#  8   Inflation (GDP Deflator, %)      2904 non-null   float64
#  9   GDP Growth (% Annual)            2912 non-null   float64
#  10  Current Account Balance (% GDP)  2563 non-null   float64
# ...

# %% [markdown]
# * As it's clear below, there are lots of missing values that we have to deal with

# %%
ds.isnull().sum()
# Out:
# country_name                          0
# country_id                            0
# year                                  0
# Inflation (CPI %)                   778
# GDP (Current USD)                   539
# GDP per Capita (Current USD)        534
# Unemployment Rate (%)               677
# Interest Rate (Real, %)            1737
# Inflation (GDP Deflator, %)         568
# GDP Growth (% Annual)               560
# Current Account Balance (% GDP)     909
# Government Expense (% of GDP)      1652
# Government Revenue (% of GDP)      1643
# Tax Revenue (% of GDP)             1639
# Gross National Income (USD)         676
# Public Debt (% of GDP)             2620
# dtype: int64

# %% [markdown]
# * Here are some statistic, keep in mind that it's not accurate because of the missing values

# %%
ds.describe()
# Out:
#               year  Inflation (CPI %)  GDP (Current USD)  \
# count  3472.000000        2694.000000       2.933000e+03
# mean   2017.500000           6.233154       3.964323e+11
# std       4.610436          19.726903       1.749315e+12
# min    2010.000000          -6.687321       3.210541e+07
# 25%    2013.750000           1.402112       6.264757e+09
# 50%    2017.500000           3.213523       2.587360e+10
# 75%    2021.250000           6.186626       1.874939e+11
# max    2025.000000         557.201817       2.772071e+13
#
#        GDP per Capita (Current USD)  Unemployment Rate (%)  \
# count                   2938.000000            2795.000000
# mean                   18483.495612               7.841141
# std                    27301.814024               5.964358
# min                      193.007146               0.100000
# 25%                     2280.748732               3.611000
# 50%                     6827.668145               5.771000
# ...

# %% [markdown]
# * There's no duplications in this dataset, which is perfect

# %%
ds.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Handling the missing values

# %% [markdown]
# * The best way the deal with the missing values is the drop them from the dataset especially if they are few and the dataset are not time series
#
# * In our case, we don't have this option (droping), so we have to deal with the missing values
#
# * The ideal way to fill the missing values is by using the global values instead of backfill or forwardfill

# %%
global_maps = {
    "Inflation (CPI %)": {
        2010: 3.1, 2011: 3.7, 2012: 3.5, 2013: 3.2, 2014: 2.9,
        2015: 2.5, 2016: 2.2, 2017: 2.6, 2018: 2.9, 2019: 3.1,
        2020: 2.3, 2021: 3.7, 2022: 6.1, 2023: 5.0, 2024: 3.8, 2025: 3.2
    },
    "GDP (Current USD)": {
        2010: 63300e9, 2011: 71000e9, 2012: 74000e9, 2013: 77000e9,
        2014: 79000e9, 2015: 75000e9, 2016: 77000e9, 2017: 81000e9,
        2018: 86000e9, 2019: 88000e9, 2020: 84000e9, 2021: 94000e9,
        2022: 101000e9, 2023: 106000e9, 2024: 110000e9, 2025: 115000e9
    },
    "GDP per Capita (Current USD)": {
        2010: 9200, 2011: 9600, 2012: 9800, 2013: 10200, 2014: 10400,
        2015: 10200, 2016: 10500, 2017: 11000, 2018: 11500, 2019: 11800,
        2020: 11300, 2021: 12200, 2022: 12700, 2023: 13200, 2024: 13600, 2025: 14100
    },
    "Unemployment Rate (%)": {
        2010: 7.2, 2011: 7.5, 2012: 7.6, 2013: 7.4, 2014: 7.1,
        2015: 6.9, 2016: 6.8, 2017: 6.6, 2018: 6.4, 2019: 6.2,
        2020: 7.9, 2021: 7.5, 2022: 6.8, 2023: 6.3, 2024: 6.1, 2025: 6.0
    },
    "Interest Rate (Real, %)": {
        2010: 2.3, 2011: 2.0, 2012: 1.8, 2013: 1.7, 2014: 1.6,
        2015: 1.3, 2016: 1.2, 2017: 1.4, 2018: 1.6, 2019: 1.7,
        2020: 0.9, 2021: 0.6, 2022: -0.5, 2023: 0.3, 2024: 1.1, 2025: 1.4
    },
    "Inflation (GDP Deflator, %)": {
        2010: 2.9, 2011: 3.4, 2012: 3.1, 2013: 2.8, 2014: 2.6,
        2015: 2.3, 2016: 2.0, 2017: 2.4, 2018: 2.6, 2019: 2.8,
        2020: 2.1, 2021: 3.5, 2022: 5.9, 2023: 4.7, 2024: 3.4, 2025: 2.9
    },
    "GDP Growth (% Annual)": {
        2010: 4.3, 2011: 3.9, 2012: 3.5, 2013: 3.4, 2014: 3.3,
        2015: 3.1, 2016: 3.0, 2017: 3.4, 2018: 3.6, 2019: 3.2,
        2020: -3.1, 2021: 5.8, 2022: 3.1, 2023: 2.8, 2024: 3.2, 2025: 3.4
    },
    "Current Account Balance (% GDP)": {
        2010: -1.4, 2011: -1.3, 2012: -1.2, 2013: -1.1, 2014: -1.0,
        2015: -1.2, 2016: -1.3, 2017: -1.4, 2018: -1.5, 2019: -1.6,
        2020: -1.9, 2021: -1.6, 2022: -1.3, 2023: -1.1, 2024: -0.9, 2025: -0.8
    },
    "Government Expense (% of GDP)": {
        2010: 27.5, 2011: 27.0, 2012: 26.8, 2013: 26.4, 2014: 26.0,
        2015: 26.2, 2016: 26.5, 2017: 26.3, 2018: 26.1, 2019: 26.0,
        2020: 30.5, 2021: 29.0, 2022: 27.8, 2023: 27.1, 2024: 26.5, 2025: 26.0
    },
    "Government Revenue (% of GDP)": {
        2010: 26.0, 2011: 25.8, 2012: 25.6, 2013: 25.4, 2014: 25.2,
        2015: 25.0, 2016: 25.1, 2017: 25.4, 2018: 25.6, 2019: 25.7,
        2020: 24.0, 2021: 24.7, 2022: 25.0, 2023: 25.4, 2024: 25.6, 2025: 25.8
    },
    "Tax Revenue (% of GDP)": {
        2010: 14.8, 2011: 14.9, 2012: 15.0, 2013: 15.1, 2014: 15.2,
        2015: 15.3, 2016: 15.4, 2017: 15.5, 2018: 15.6, 2019: 15.7,
        2020: 15.2, 2021: 15.4, 2022: 15.6, 2023: 15.7, 2024: 15.9, 2025: 16.0
    },
    "Gross National Income (USD)": {
        2010: 62000e9, 2011: 69000e9, 2012: 71000e9, 2013: 74000e9,
        2014: 76000e9, 2015: 72000e9, 2016: 74000e9, 2017: 78000e9,
        2018: 83000e9, 2019: 85000e9, 2020: 81000e9, 2021: 91000e9,
        2022: 98000e9, 2023: 103000e9, 2024: 107000e9, 2025: 112000e9
    },
    "Public Debt (% of GDP)": {
        2010: 63.1, 2011: 64.8, 2012: 65.4, 2013: 66.0, 2014: 67.2,
        2015: 68.4, 2016: 69.3, 2017: 70.1, 2018: 70.8, 2019: 71.5,
        2020: 83.5, 2021: 81.2, 2022: 79.0, 2023: 76.3, 2024: 74.2, 2025: 72.0
    }
}

# %%
for col in global_maps:
    print(col)
# Out:
# Inflation (CPI %)
# GDP (Current USD)
# GDP per Capita (Current USD)
# Unemployment Rate (%)
# Interest Rate (Real, %)
# Inflation (GDP Deflator, %)
# GDP Growth (% Annual)
# Current Account Balance (% GDP)
# Government Expense (% of GDP)
# Government Revenue (% of GDP)
# Tax Revenue (% of GDP)
# Gross National Income (USD)
# Public Debt (% of GDP)

# %% [markdown]
# * We did fill all missing values using global values

# %%
for col in global_maps:
    ds[col] = ds[col].fillna(ds["year"].map(global_maps[col]))

# %% [markdown]
# * Double check ✅

# %%
ds.isnull().sum()
# Out:
# country_name                       0
# country_id                         0
# year                               0
# Inflation (CPI %)                  0
# GDP (Current USD)                  0
# GDP per Capita (Current USD)       0
# Unemployment Rate (%)              0
# Interest Rate (Real, %)            0
# Inflation (GDP Deflator, %)        0
# GDP Growth (% Annual)              0
# Current Account Balance (% GDP)    0
# Government Expense (% of GDP)      0
# Government Revenue (% of GDP)      0
# Tax Revenue (% of GDP)             0
# Gross National Income (USD)        0
# Public Debt (% of GDP)             0
# dtype: int64

# %%
ds.sample(5)
# Out:
#      country_name country_id  year  Inflation (CPI %)  GDP (Current USD)  \
# 1980   Madagascar         mg  2022           8.160590       1.513470e+10
# 102     Argentina         ar  2016           2.200000       5.575323e+11
# 44         Angola         ao  2022          21.355290       1.043997e+11
# 430        Brazil         br  2024           4.367464       1.100000e+14
# 1175  Gambia, The         gm  2017           8.034190       1.504909e+09
#
#       GDP per Capita (Current USD)  Unemployment Rate (%)  \
# 1980                    497.242515                  3.186
# 102                   12699.962314                  8.085
# 44                     2929.694455                 14.602
# 430                   13600.000000                  7.634
# 1175                    642.522641                  5.157
#
#       Interest Rate (Real, %)  Inflation (GDP Deflator, %)  \
# 1980                39.183769                     6.932966
# ...

# %% [markdown]
# * Before we upload the dataset into MySQL, it's better to make the columns easy to get

# %%
ds.columns
# Out:
# Index(['country_name', 'country_id', 'year', 'Inflation (CPI %)',
#        'GDP (Current USD)', 'GDP per Capita (Current USD)',
#        'Unemployment Rate (%)', 'Interest Rate (Real, %)',
#        'Inflation (GDP Deflator, %)', 'GDP Growth (% Annual)',
#        'Current Account Balance (% GDP)', 'Government Expense (% of GDP)',
#        'Government Revenue (% of GDP)', 'Tax Revenue (% of GDP)',
#        'Gross National Income (USD)', 'Public Debt (% of GDP)'],
#       dtype='object')

# %%
ds.columns = ["country_name", "country_id", "year", "Inflation CPI", "GDP",
              "GDP per Capita", "Unemployment Rate", "Interest Rate",
              "Inflation Deflator", "GDP Growth", "Current Account Balance",
              "Government Expense", "Government Revenue", "Tax Revenue",
              "Gross National Income", "Public Debt"]

# %%
ds.head(4)
# Out:
#   country_name country_id  year  Inflation CPI           GDP  GDP per Capita  \
# 0        Aruba         aw  2010       2.078141  2.453597e+09    24093.140151
# 1        Aruba         aw  2011       4.316297  2.637859e+09    25712.384302
# 2        Aruba         aw  2012       0.627472  2.615208e+09    25119.665545
# 3        Aruba         aw  2013      -2.372065  2.727850e+09    25813.576727
#
#    Unemployment Rate  Interest Rate  Inflation Deflator  GDP Growth  \
# 0                7.2      11.666131           -1.223407   -2.733457
# 1                7.5       4.801974            4.005674    3.369237
# 2                7.6       8.200875            0.184033   -1.040800
# 3                7.4      10.709709           -1.995948    6.431483
#
#    Current Account Balance  Government Expense  Government Revenue  \
# 0               -18.752537                27.5                26.0
# 1                -9.877656                27.0                25.8
# ...

# %% [markdown]
# ### Uploading Dataset into MySQL

# %% [markdown]
# * Important Libararies

# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.7 MB/s eta 0:00:00
# ...

# %%
import pymysql
from sqlalchemy import create_engine

# %%
engin = create_engine("mysql+pymysql://root:root.com@localhost:3306/Macroeconomic_DS")

# To check if it works
try:
  engin
  print("connection seccessed to MySQL")

except:
  print("there is an issue")
# Out:
# connection seccessed to MySQL

# %%
ds.to_sql(name="Macroeconomic", con=engin, if_exists= 'append', index=False)

# %% [markdown]
# * Downloading the dataset (Optional)

# %%
ds.to_csv("Macroeconomic_Cleaned.csv", index=False)
